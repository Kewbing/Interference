# %% [markdown]
# ### k=20,耗时642s

# %%
# -*- coding: utf-8 -*-
import time
start = time.time()
import numpy as np
import pandas as pd
from itertools import groupby
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")
engine = create_engine('mssql+pymssql://sa:bc_123456@172.16.52.223/YUXB_NJ_5G',connect_args={'charset':'utf8'})

#1、加载数据
table = ['data_cell_kmeans','data_cell_kmeans1']
for i in table:
    print(i)
    data = pd.read_sql_table(i, engine)
    data.sort_values("Date",ascending=True,inplace=True)
    data3 = pd.pivot_table(data,index ='CGI',values='Flow',columns='Date')
    data3 = data3.reset_index( drop=False )
    #data3.columns =['CGI','2021-1-1','2021-1-2','2021-1-3','2021-1-4','2021-1-5','2021-1-6','2021-1-7','2021-1-8','2021-1-9','2021-1-10','2021-1-11','2021-1-12','2021-1-13','2021-1-14','2021-1-15','2021-1-16','2021-1-17','2021-1-18','2021-1-19','2021-1-20','2021-1-21','2021-1-22','2021-1-23','2021-1-24','2021-1-25','2021-1-26','2021-1-27','2021-1-28','2021-1-29','2021-1-30','2021-1-31','2021-2-1','2021-2-2','2021-2-3','2021-2-4','2021-2-5','2021-2-6','2021-2-7','2021-2-8','2021-2-9','2021-2-10','2021-2-11','2021-2-12','2021-2-13','2021-2-14','2021-2-15','2021-2-16','2021-2-17','2021-2-18','2021-2-19','2021-3-1','2021-3-2','2021-3-3','2021-3-4','2021-3-5','2021-3-6','2021-3-7','2021-3-8','2021-3-9','2021-3-10','2021-3-11','2021-3-12','2021-3-13','2021-3-14','2021-3-16','2021-3-17','2021-3-18','2021-3-19','2021-3-20','2021-3-21','2021-3-22','2021-3-23','2021-3-24','2021-3-25','2021-3-26','2021-3-27','2021-3-28','2021-3-29','2021-3-30','2021-3-31','2021-4-1','2021-4-2','2021-4-3','2021-4-4','2021-4-5','2021-4-6','2021-4-7','2021-4-8','2021-4-9','2021-4-10','2021-4-11','2021-4-12','2021-4-13','2021-4-14','2021-4-15','2021-4-16','2021-4-17','2021-4-18','2021-4-19','2021-4-20','2021-4-21','2021-4-22','2021-4-23','2021-4-24','2021-4-25','2021-4-26','2021-4-27','2021-4-28','2021-4-29','2021-4-30','2021-5-1','2021-5-2','2021-5-3','2021-5-4','2021-5-5','2021-5-6','2021-5-7','2021-5-8','2021-5-9','2021-5-10','2021-5-11','2021-5-12','2021-5-13','2021-5-14','2021-5-15','2021-5-16','2021-5-17','2021-5-18','2021-5-19','2021-5-20','2021-5-21','2021-5-22','2021-5-23','2021-5-24','2021-5-25','2021-5-26','2021-5-27','2021-5-28','2021-5-29','2021-5-30','2021-5-31','2021-6-1','2021-6-2','2021-6-3','2021-6-4','2021-6-5','2021-6-6','2021-6-7','2021-6-8','2021-6-9','2021-6-10','2021-6-11','2021-6-12','2021-6-13','2021-6-14','2021-6-15','2021-6-16','2021-6-17','2021-6-18','2021-6-19','2021-6-20','2021-6-21','2021-6-22','2021-6-23','2021-6-24','2021-6-25','2021-6-26','2021-6-27','2021-6-28','2021-6-29','2021-6-30','2021-7-1','2021-7-2','2021-7-3','2021-7-4','2021-7-5','2021-7-6','2021-7-7','2021-7-8','2021-7-9','2021-7-10','2021-7-11','2021-7-12','2021-7-13','2021-7-14','2021-7-15','2021-7-16','2021-7-17','2021-7-18','2021-7-19','2021-7-20','2021-7-21','2021-7-22','2021-7-23','2021-7-24','2021-7-25','2021-7-26','2021-7-27','2021-7-28','2021-7-29','2021-7-30','2021-7-31']
    if i == 'data_cell_kmeans':
        data3.to_csv(r'C:\Users\24407\干扰\Flow_data\data_cell_Upilot.csv', index=False ,mode='a' , header=True)
    elif i != 'data_cell_kmeans':
        data3.to_csv(r'C:\Users\24407\干扰\Flow_data\data_cell_Upilot.csv', index=False ,mode='a' , header=False)
        #223数据库慢，改成保存到本地CSV文件
        #data3.to_sql(name='data_cell_Upilot', con=engine, chunksize=1000, if_exists='append', index=None)#append、replace
    end = time.time()
    print (end-start)
# Out:
# data_cell_kmeans
# 156.5010645389557
# data_cell_kmeans1
# 327.4918842315674

# %%
# -*- coding: utf-8 -*-
import time
start = time.time()
import numpy as np
import pandas as pd
from itertools import groupby
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")
engine = create_engine('mssql+pymssql://sa:bc_123456@172.16.52.223/YUXB_NJ_5G',connect_args={'charset':'utf8'})
# 读取转换后的数据
input_path = r'C:\Users\24407\干扰\Flow_data\data_cell_Upilot.csv'


from sklearn.cluster import KMeans
data = pd.read_csv(input_path, index_col='CGI')
model = KMeans(n_clusters=k, n_jobs=1, max_iter=iteration)  
data = data.fillna(0)

k = 20 # 聚类的类别
iteration = 500  # 聚类最大迭代次数
data_zs = 1.0*(data - data.mean())/data.std()  # 数据标准化
model.fit(data_zs)  # 开始聚类

# 详细输出原始数据及其类别
output_data = pd.concat([data, pd.Series(model.labels_, index=data.index)], axis=1)   
output_data.columns = list(data.columns) +  ['聚类类别']   # 重命名表头

gongcan_data = pd.read_sql_table('ips_web_cell', engine)#场景数据
gongcan_data = gongcan_data[['CGI','SceneType']]
display(gongcan_data.head())
output_data = pd.merge(output_data , gongcan_data ,how='left', on = 'CGI')
CGI_List = output_data[['CGI','SceneType','聚类类别']]
CGI_List['SceneType'] = CGI_List['SceneType'].replace(np.nan,'其它')

CGI_List.to_sql(name='data_ClusterId', con=engine, chunksize=1000, if_exists='append', index=None)#append、replace

output_data = output_data.reset_index(drop=False)
output_data.to_sql(name='data_SceneType_result', con=engine, chunksize=1000, if_exists='append', index=None)#append、replace
end = time.time()
print (end-start)
# Out:
#                     2021-01-01    2021-01-02    2021-01-03    2021-01-04  \
# CGI
# 460-00-327683-12  1.301026e+07  1.339216e+07  3.210666e+07  4.412894e+07
# 460-00-327683-13  2.379952e+06  1.598420e+06  1.804516e+07  2.193761e+07
# 460-00-327683-14  9.459617e+05  1.460091e+06  7.345996e+06  1.131620e+07
# 460-00-327683-15  6.511402e+06  7.161557e+06  2.150656e+07  3.461724e+07
# 460-00-327683-16  1.993194e+07  2.310317e+07  2.711078e+07  3.761796e+07
#
#                     2021-01-05    2021-01-06    2021-01-07    2021-01-08  \
# CGI
# 460-00-327683-12  5.359689e+07  6.119371e+07  6.462062e+07  5.792604e+07
# 460-00-327683-13  3.189536e+07  3.712118e+07  4.212961e+07  5.586101e+07
# 460-00-327683-14  1.423888e+07  1.866222e+07  1.864286e+07  1.896669e+07
# 460-00-327683-15  5.785567e+07  6.103593e+07  5.224348e+07  5.663352e+07
# 460-00-327683-16  3.908074e+07  4.312543e+07  3.924153e+07  4.233714e+07
#
# ...

# %%
# -*- coding: utf-8 -*-
import time
start = time.time()
import numpy as np
import pandas as pd
from itertools import groupby
from sqlalchemy import create_engine
import warnings

warnings.filterwarnings("ignore")
engine = create_engine('mssql+pymssql://sa:bc_123456@172.16.52.223/YUXB_NJ_5G')

#1、编号重置+导出聚类数据
ClusterData = pd.read_sql_table('data_SceneType_result', engine)
Data = ClusterData[['SceneType','聚类类别']]
Data = Data.drop_duplicates()
Data['ClusterId'] = Data.index.values

ClusterData = pd.merge(ClusterData,Data,how ='left', on=['SceneType','聚类类别'])
Clusterlist = list(ClusterData['ClusterId'])

for i in  Clusterlist:
    Data1=ClusterData.loc[(ClusterData['ClusterId'] == i)]
    Data1 = Data1.drop(columns=['聚类类别','SceneType','ClusterId'])
    Data1=Data1.T
    Data1['date'] = Data1.index.values
    Data1.columns = ['value','date']
    Data1.to_csv(r'C:\\Users\\24407\\干扰\\Flow_data\\data\\result\\'+str(i)+'.csv', index=False  , header=True)

#2、导出ClusterId清单
ClusterId = pd.read_sql_table('data_ClusterId', engine)
ClusterId = pd.merge(ClusterId,Data,how ='left', on=['SceneType','聚类类别'])
ClusterId= ClusterId[['CGI','ClusterId']]
ClusterId.columns =['CGI','ClusterId']
ClusterId.sort_values("ClusterId",ascending=True,inplace=True)
ClusterId.to_csv('C:\\Users\\24407\\干扰\\Flow_data\\data\\CgiList.csv', index=False  , header=True)
