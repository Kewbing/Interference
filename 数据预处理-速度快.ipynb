# %%
# -*- coding: utf-8 -*-
import time
start = time.time()
import numpy as np
import pandas as pd
from itertools import groupby
from sqlalchemy import create_engine
engine = create_engine('mssql+pymssql://sa:bc_123456@172.16.52.223/YUXB_NJ_5G',connect_args={'charset':'utf8'})

import warnings
warnings.filterwarnings("ignore")
#1、加载数据
table = ['data_cell_test_output','data_cell_test_output2']
for i in table:
    data = pd.read_sql_table(i, engine)
    data.sort_values("Date",ascending=True,inplace=True)
    data3 = pd.pivot_table(data,index ='CGI',values='Flow',columns='Date')
    data3.to_csv('C:\\Users\\24407\\OneDrive\\桌面\\Flow_data\\'+'data_cell_Upilot'+'.csv'
                 , index=True ,mode='a' , header=False)
end = time.time()
print (end-start)
# Out:
# 1133.766505241394
